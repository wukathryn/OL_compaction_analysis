# %% [markdown]
# #Identify outliers while being blinded to condition

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import seaborn as sns

import sys
src_path = str(Path.cwd().parent)
if src_path not in sys.path:
    sys.path.append(src_path)
import microscopy_analysis.d00_utils.utilities as utils
import microscopy_analysis.d00_utils.dirnames as dn

# %%
df_path = Path(input())

# %%
well_cond_df_path = Path(input())

# %%
tables_dirpath = utils.get_proc_dirpath(df_path) / dn.tables_dirname

# %%
df = pd.read_csv(df_path)
df.head()

# %%
namesplits = df['ROI imgname'].str.split('.ome.tif').str[0].str.replace('-', '_').str.split('_')
for i, elem in enumerate(namesplits[0]):
    print(f'{i}: {elem}')

# %%
df['wellID'] = namesplits.str[0] + '-' + namesplits.str[2] + '-' + namesplits.str[3]
df['scene'] = namesplits.str[4]
df['ROI'] = namesplits.str[6]
df['UID'] = df['wellID'] + '-' + df['scene'] + '-' + df['ROI']
df.head()

# %%
well_cond_df = pd.read_csv(well_cond_df_path)
well_cond_df.head()

# %%
premerge_df_len = len(df)
df = pd.merge(df, well_cond_df, how = "left")
assert premerge_df_len==len(df)
df.head()

# %%
utils.safe_save_csv(df, df_path)
