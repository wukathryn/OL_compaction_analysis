# %% [markdown]
# # Standardize well conditions: genetic-actin experiments
#
# Map condition labels from the genetic-actin experiment series onto the canonical condition vocabulary used by the manuscript figures.

# %%
df_path = Path(input())

# %%
df = pd.read_csv(df_path)
df.head()

# %%
well_cond_key_path = Path('/Users/kwu2/Library/CloudStorage/GoogleDrive-kwu2@stanford.edu/My Drive/Lab/CryoEM_live_imaging/Experiments/actin_genetic_exp/data/well_cond_key.csv')

# %%
key_df = pd.read_csv(well_cond_key_path)
key_df

# %%
txs = df['tx'].unique()
txs

# %%
df = df[['experiment', 'wellID', 'DIV', 'tx']]
df

# %%
df = pd.merge(df, key_df, how='left', on='tx')
df

# %%
df['tech rep'] = df.groupby(['tx', 'DIV']).cumcount() + 1
df

# %%
cols = df.columns.to_list()
for i, col in enumerate(cols):
    print(f'{i}: {col}')

# %%
new_col_order = ['experiment', 'wellID', 'DIV', 'tx', 'condition', 'ch0', 'ch1', 'ch2', 'ch3', 'caax ch to process', 'cell ch']

# %%
df = df[new_col_order]
df.head()

# %%
utils.safe_save_csv(df, df_path)
