# %%
from pathlib import Path
import numpy as np
import pandas as pd

import sys
src_path = str(Path.cwd().parent.parent)
if src_path not in sys.path:
    sys.path.append(src_path)

from src.d00_utils import utilities as utils
from src.d00_utils import dirnames as dn

# %%
# combine df

# %%
df_1_path = Path(input())

# %%
df_2_path = Path(input())

# %%
df_3_path = Path(input())

# %%
df_1 = pd.read_csv(df_1_path)
df_2 = pd.read_csv(df_2_path)
df_3 = pd.read_csv(df_3_path)

# %%
df_3.head()

# %%
df = pd.concat([df_1, df_2, df_3])

print(len(df))
df

# %%
savepath = output_dirpath / 'combined_cmp_zone_analysis.csv'
utils.safe_save_csv(df, savepath)

# %%
df = pd.read_csv(savepath)
df.head()

# %%
cols = df.columns.to_list()
print(f'num cols: {len(cols)}')
for i, col in enumerate(cols):
    print(f'{i}: {col}')

# %%
new_col_order = ['ROI imgname', 'experiment', 'scene', 'wellID', 'ROI', 'UID', 'DIV', 'tx', 'time interval', 't', 'elapsed time (hr)', 'first post-tx t', 'tx status', 'virus', 'ch0', 'ch1', 'ch2', 'caax ch', 'cell ch', 'label', 'area (pixels^2)', 'area (microns^2)']

omitted_cols = [col for col in cols if col not in new_col_order ]
omitted_cols

# %%
df = df[new_col_order]
df

# %%
utils.safe_save_csv(df, savepath)
